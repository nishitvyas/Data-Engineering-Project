# %%
# Path where my Access key file is present. This Access key is generated on Amazon S3 Management Console.
/FileStore/tables/new_user_credentials.csv

# %%
# pyspark functions
from pyspark.sql.functions import *
# URL processing
import urllib

# %%
# Define file type
file_type = "csv"
# Whether the file has a header
first_row_is_header = "true"
# Delimiter used in the file
delimiter = ","
# Read the CSV file to spark dataframe
aws_keys_df = spark.read.format(file_type)\
.option("header", first_row_is_header)\
.option("sep", delimiter)\
.load("/FileStore/tables/new_user_credentials.csv")

# %%
#test_user
# Get the AWS access key and secret key from the spark dataframe
ACCESS_KEY = aws_keys_df.where(col('User name')=='test_user').select('Access key ID').collect()[0]['Access key ID']
SECRET_KEY = aws_keys_df.where(col('User name')=='test_user').select('Secret access key').collect()[0]['Secret access key']
# Encode the secrete key
ENCODED_SECRET_KEY = urllib.parse.quote(string=SECRET_KEY, safe="")

# %%
# AWS S3 bucket name
AWS_S3_BUCKET = "marketbasketbucket"
# Mount name for the bucket
MOUNT_NAME = "/mnt/mba/chunks"
# Source url
SOURCE_URL = "s3n://{0}:{1}@{2}".format(ACCESS_KEY, ENCODED_SECRET_KEY, AWS_S3_BUCKET)
# Mount the drive
dbutils.fs.mount(SOURCE_URL, MOUNT_NAME)
# Out:
# Out[6]: True

# %%
#display(dbutils.fs.ls("/mnt/crypto-price-prediction/g-research-crypto-forecasting/"))
display(dbutils.fs.ls("/mnt/mba/chunks/"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/mnt/mba/chunks/chunk0.csv</td><td>chunk0.csv</td><td>1879965126</td><td>1651078878000</td></tr><tr><td>dbfs:/mnt/mba/chunks/chunk1.csv</td><td>chunk1.csv</td><td>1883313499</td><td>1651078878000</td></tr><tr><td>dbfs:/mnt/mba/chunks/chunk3.csv</td><td>chunk3.csv</td><td>60217456</td><td>1651078878000</td></tr></tbody></table></div>

# %%
from pyspark.sql.types import *
# File Schema
file_schema = StructType([
    StructField('event_time', StringType(), False),
    StructField('event_type', StringType(), True),
    StructField('product_id', IntegerType(), True),
    StructField('category_id', LongType(), True),
    StructField('category_code', StringType(), True),
    StructField('brand', StringType(), True),
    StructField('price', FloatType(), True),
    StructField('user_id', IntegerType(), True),
    StructField('user_session', StringType(), True)
])

#Creating an empty dataframe with the same schema
maindf = spark.createDataFrame([], file_schema)

# The applied options are for CSV files. For other file types, these will be ignored.
for i in dbutils.fs.ls("dbfs:/mnt/mba/chunks/"):
    df = spark.read.csv(path= i.path, header=True, schema=file_schema)
    maindf = maindf.union(df)
    
    #spark.read.csv(file_location, header=True, schema= file_schema)
    

maindf.show(10, truncate=False)
# Out:
# +-----------------------+----------+----------+-------------------+-----------------------------------+--------+-------+---------+------------------------------------+
# |event_time             |event_type|product_id|category_id        |category_code                      |brand   |price  |user_id  |user_session                        |
# +-----------------------+----------+----------+-------------------+-----------------------------------+--------+-------+---------+------------------------------------+
# |2019-10-01 00:00:00 UTC|view      |44600062  |2103807459595387724|null                               |shiseido|35.79  |541312140|72d76fde-8bb3-4e00-8c23-a032dfed738c|
# |2019-10-01 00:00:00 UTC|view      |3900821   |2053013552326770905|appliances.environment.water_heater|aqua    |33.2   |554748717|9333dfbd-b87a-4708-9857-6336556b0fcc|
# |2019-10-01 00:00:01 UTC|view      |17200506  |2053013559792632471|furniture.living_room.sofa         |null    |543.1  |519107250|566511c2-e2e3-422b-b695-cf8e6e792ca8|
# |2019-10-01 00:00:01 UTC|view      |1307067   |2053013558920217191|computers.notebook                 |lenovo  |251.74 |550050854|7c90fc70-0e80-4590-96f3-13c02c18c713|
# |2019-10-01 00:00:04 UTC|view      |1004237   |2053013555631882655|electronics.smartphone             |apple   |1081.98|535871217|c6bd7419-2748-4c56-95b4-8cec9ff8b80d|
# |2019-10-01 00:00:05 UTC|view      |1480613   |2053013561092866779|computers.desktop                  |pulser  |908.62 |512742880|0d0d91c2-c9c2-4e81-90a5-86594dec0db9|
# |2019-10-01 00:00:08 UTC|view      |17300353  |2053013553853497655|null                               |creed   |380.96 |555447699|4fe811e9-91de-46da-90c3-bbd87ed3a65d|
# |2019-10-01 00:00:08 UTC|view      |31500053  |2053013558031024687|null                               |luminarc|41.16  |550978835|6280d577-25c8-4147-99a7-abc6048498d6|
# |2019-10-01 00:00:10 UTC|view      |28719074  |2053013565480109009|apparel.shoes.keds                 |baden   |102.71 |520571932|ac1cd4e5-a3ce-4224-a2d7-ff660a105880|
# |2019-10-01 00:00:11 UTC|view      |1004545   |2053013555631882655|electronics.smartphone             |huawei  |566.01 |537918940|406c46ed-90a4-4787-a43b-59a410c1a5fb|
# +-----------------------+----------+----------+-------------------+-----------------------------------+--------+-------+---------+------------------------------------+
# only showing top 10 rows

# %%
maindf.count()
# Out:
# Out[24]: 28448765

# %%
dbutils.fs.unmount(MOUNT_NAME)
# Out:
# /mnt/mba/chunks has been unmounted.
# Out[26]: True

# %%
# Create a view or table

temp_table_name = "chunk0-1_csv"

df.createOrReplaceTempView(temp_table_name)

# %%
# import necessary libraries
from pyspark.sql.types import *
# pyspark functions
from pyspark.sql.functions import *
# URL processing
import urllib

##########################################################################################################################################
##################################################### Data Reading & Combining Section ###################################################
##########################################################################################################################################


# Define file type
file_type = "csv"
# Whether the file has a header
first_row_is_header = "true"
# Delimiter used in the file
delimiter = ","
# Read the CSV file to spark dataframe
aws_keys_df = spark.read.format(file_type)\
.option("header", first_row_is_header)\
.option("sep", delimiter)\
.load("/FileStore/tables/new_user_credentials.csv")

#test_user
# Get the AWS access key and secret key from the spark dataframe
ACCESS_KEY = aws_keys_df.where(col('User name')=='test_user').select('Access key ID').collect()[0]['Access key ID']
SECRET_KEY = aws_keys_df.where(col('User name')=='test_user').select('Secret access key').collect()[0]['Secret access key']
# Encode the secrete key
ENCODED_SECRET_KEY = urllib.parse.quote(string=SECRET_KEY, safe="")

# AWS S3 bucket name
AWS_S3_BUCKET = "marketbasketbucket"
# Mount name for the bucket
MOUNT_NAME = "/mnt/mba/chunks"
# Source url
SOURCE_URL = "s3n://{0}:{1}@{2}".format(ACCESS_KEY, ENCODED_SECRET_KEY, AWS_S3_BUCKET)
# Mount the drive
dbutils.fs.mount(SOURCE_URL, MOUNT_NAME)


# Reading and Combining the csv files
from pyspark.sql.types import *
# File Schema
file_schema = StructType([
    StructField('event_time', StringType(), False),
    StructField('event_type', StringType(), True),
    StructField('product_id', IntegerType(), True),
    StructField('category_id', LongType(), True),
    StructField('category_code', StringType(), True),
    StructField('brand', StringType(), True),
    StructField('price', FloatType(), True),
    StructField('user_id', IntegerType(), True),
    StructField('user_session', StringType(), True)
])

#Creating an empty dataframe with the same schema
maindf = spark.createDataFrame([], file_schema)

# The applied options are for CSV files. For other file types, these will be ignored.
for i in dbutils.fs.ls("dbfs:/mnt/mba/chunks/"):
    df = spark.read.csv(path= i.path, header=True, schema=file_schema)
    maindf = maindf.union(df)
    
    
#Show the Dataframe if required
#maindf.show(10, truncate=False)




##########################################################################################################################################
##################################################### Data Transformation Section ########################################################
##########################################################################################################################################
#DataFlow

# Compress the data and store in an optimized format.


#Missing Values
nonNAdf = maindf.where(maindf.category_code.isNotNull())


#Separate_productTypes
import pyspark.sql.functions as F
from pyspark.sql.types import *
from pyspark.sql.functions import isnan, when, count, col

def string_split(string1):
    main_string = string1.split('.')[-1]
    main_string = main_string.strip()
    return main_string

udfstringfunc = F.udf(string_split, StringType())
nonNAdf = nonNAdf.withColumn('productType', udfstringfunc('category_code'))




# Events Split
nonNAdf_purchase = nonNAdf.select('*').where(col('event_type')=='purchase')
nonNAdf_view = nonNAdf.select('*').where(col('event_type')=='view')
nonNAdf_cart = nonNAdf.select('*').where(col('event_type')=='cart')


#groupby users Purchase
grouped_transactions = nonNAdf_purchase.select('*').groupBy('user_session').agg(F.concat_ws(",",F.collect_list(nonNAdf_purchase.productType))).select(col('user_session').alias('sid'), col("concat_ws(,, collect_list(productType))").alias("transactions"))


#join the table
grouped_transactions = grouped_transactions.join(nonNAdf_purchase, grouped_transactions.sid==nonNAdf_purchase.user_session, 'left')
grouped_transactions= grouped_transactions.drop(*['sid', 'category_id'])
grouped_transactions.cache()

#Un Mount the mount as we have final data in maindf DataFrame
dbutils.fs.unmount(MOUNT_NAME)#Un Mount the mount as we have final data in maindf DataFrame
dbutils.fs.unmount(MOUNT_NAME)
# Out:
# Out[3]: DataFrame[transactions: string, event_time: string, event_type: string, product_id: int, category_code: string, brand: string, price: float, user_id: int, user_session: string, productType: string]

# %%
grouped_transactions.show(100, truncate=True)
# Out:
# +--------------------+--------------------+----------+----------+--------------------+-----------+-------+---------+--------------------+-------------+
# |        transactions|          event_time|event_type|product_id|       category_code|      brand|  price|  user_id|        user_session|  productType|
# +--------------------+--------------------+----------+----------+--------------------+-----------+-------+---------+--------------------+-------------+
# |                  tv|2019-10-31 17:15:...|  purchase|   1801938|electronics.video.tv|       sony|1543.39|514674061|0026da65-d60b-4d7...|           tv|
# |            notebook|2019-10-11 02:34:...|  purchase|   1307377|  computers.notebook|     lenovo| 434.99|538672167|00326296-8877-47f...|     notebook|
# |           subwoofer|2019-10-16 07:43:...|  purchase|   5801483|electronics.audio...|    pioneer|  58.95|513593613|0032e941-8533-46a...|    subwoofer|
# |          smartphone|2019-10-01 13:19:...|  purchase|   1004173|electronics.smart...|     xiaomi| 146.46|551801399|0056e55b-b2fe-4b9...|   smartphone|
# |          smartphone|2019-10-13 11:41:...|  purchase|   1002544|electronics.smart...|      apple|  460.5|538360990|0065778b-d87b-48a...|   smartphone|
e7d1e5523e</td><td>costume</td></tr><tr><td>headphone</td><td>2019-10-13 12:12:56 UTC</td><td>purchase</td><td>4804056</td><td>electronics.audio.headphone</td><td>apple</td><td>161.87</td><td>515918800</td><td>00fbed77-d3a6-4664-a53b-28968f918a9c</td><td>headphone</td></tr><tr><td>smartphone</td><td>2019-10-31 18:27:32 UTC</td><td>purchase</td><td>1004249</td><td>electronics.smartphone</td><td>apple</td><td>722.4</td><td>559257570</td><td>01110858-a475-4210-880f-2e2f13d41dc1</td><td>smartphone</td></tr><tr><td>refrigerators</td><td>2019-10-15 18:18:54 UTC</td><td>purchase</td><td>2701333</td><td>appliances.kitchen.refrigerators</td><td>samsung</td><td>952.38</td><td>517531951</td><td>012a8c40-99bd-4279-a6f1-a9a2a2eabef6</td><td>refrigerators</td></tr><tr><td>smartphone</td><td>2019-10-19 06:21:22 UTC</td><td>purchase</td><td>1004856</td><td>electronics.smartphone</td><td>samsung</td><td>131.53</td><td>561416720</td><td>013d60d1-6e1c-46d6-ac80-78bf8b6f354e</td><td>smartphone</td></tr><tr><td>headphone</td><td>2019-10-19 07:35:46 UTC</td><td>purchase</td><td>4804056</td><td>electronics.audio.headphone</td><td>apple</td><td>160.62</td><td>540619065</td><td>01549504-d90f-4dff-927f-bf79e8a1e098</td><td>headphone</td></tr><tr><td>water_heater</td><td>2019-10-15 14:02:04 UTC</td><td>purchase</td><td>3900003</td><td>appliances.environment.water_heater</td><td>ariston</td><td>117.09</td><td>551537289</td><td>01613645-6f36-4762-acea-09c7caf60749</td><td>water_heater</td></tr><tr><td>smartphone</td><td>2019-10-14 04:17:43 UTC</td><td>purchase</td><td>1004785</td><td>electronics.smartphone</td><td>huawei</td><td>277.42</td><td>530865691</td><td>01654ea7-6a1a-4263-9e9e-b8df4fddcce3</td><td>smartphone</td></tr><tr><td>smartphone</td><td>2019-10-06 14:14:15 UTC</td><td>purchase</td><td>1004249</td><td>electronics.smartphone</td><td>apple</td><td>730.26</td><td>514891919</td><td>016acf77-4cfc-48c2-b23e-35e80d15b4be</td><td>smartphone</td></tr><tr><td>ebooks</td><td>2019-10-12 09:46:50 UTC</td><td>purchase</td><td>5200096</td><td>computers.ebooks</td><td>pocketbook</td><td>102.19</td><td>52222095 ...

# %%
# Code for storing the intermediate results in parquet format.
unique_transactions = grouped_transactions.select(col('user_session'), col('transactions')).dropDuplicates(['user_session'])
unique_transactions = unique_transactions.groupby('transactions').count().orderBy('count', ascending=False)
#unique_transactions.show(10, truncate=False)

unique_transactions.write.format("parquet").mode("overwrite").save("/tmp/MBA/transactionList.parquet")

# %% [markdown]
# ### Unpersist Code

# %%
## Remove the data stored in the memory
grouped_transactions.unpersist()

# %% [markdown]
# ### Unmounting Code

# %%
#Un Mount the mount as we have final data in maindf DataFrame
dbutils.fs.unmount(MOUNT_NAME)
# Out:
# /mnt/mba/chunks has been unmounted.
# Out[6]: True
